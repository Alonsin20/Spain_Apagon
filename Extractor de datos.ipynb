# %% [markdown]
# # Notebook para la extracción de datos a utilizar

# %% [markdown]
# ## 1. Seteamos la conexión con la API de Github

# %%
#Total users
import requests

def print_total_users_for_location(location="Spain", personal_access_token=None):
    if not personal_access_token:
        raise ValueError("PAT is required.")

    url = "https://api.github.com/graphql"
    headers = {
        "Authorization": f"Bearer {personal_access_token}",
        "Content-Type":  "application/json",
        "Accept":        "application/vnd.github.v3+json"
    }

    users_query = """
    query ($query: String!, $first: Int!) {
      search(query: $query, type: USER, first: $first) {
        userCount
      }
    }
    """
    variables = {
        "query": f"location:{location} type:user",
        "first": 1
    }

    resp = requests.post(url, headers=headers, json={"query": users_query, "variables": variables})
    resp.raise_for_status()
    total_user_count = resp.json()["data"]["search"]["userCount"]

    print(f"Total number of users: {total_user_count}")
    return total_user_count

if __name__ == "__main__":
    TOKEN = "" #insertar token
    print_total_users_for_location("France", TOKEN)
# Out:
# Total number of users: 127477

# %% [markdown]
# ## 2. Configuraciones adicionales para interactuar con la API

# %%
import requests
import datetime
import json
from collections import defaultdict

USER_COUNT_QUERY = """
query($query:String!,$first:Int!){
  search(query:$query, type:USER, first:$first) {
    userCount
  }
}
"""

USERS_PAGINATED_QUERY = """
query($query:String!,$first:Int!,$after:String) {
  search(query:$query, type:USER, first:$first, after:$after) {
    edges { node { ... on User { login } } }
    pageInfo { hasNextPage endCursor }
  }
}
"""

def get_user_count(query, url, headers):
    vars = {"query": query, "first": 1}
    resp = requests.post(url, headers=headers,
                         json={"query": USER_COUNT_QUERY, "variables": vars})
    resp.raise_for_status()
    return resp.json()["data"]["search"]["userCount"]

def paginated_search(query, max_slice, url, headers):
    users = []
    after = None
    while len(users) < max_slice:
        vars = {"query": query, "first": 100, "after": after}
        resp = requests.post(url, headers=headers,
                             json={"query": USERS_PAGINATED_QUERY, "variables": vars})
        resp.raise_for_status()
        data = resp.json()["data"]["search"]
        for edge in data["edges"]:
            users.append(edge["node"]["login"])
            if len(users) >= max_slice:
                break
        if not data["pageInfo"]["hasNextPage"]:
            break
        after = data["pageInfo"]["endCursor"]
    return users

def fetch_users(location, max_users, token):
    url = "https://api.github.com/graphql"
    headers = {
        "Authorization": f"Bearer {token}",
        "Content-Type":  "application/json",
        "Accept":        "application/vnd.github.v3+json"
    }

    start_date = datetime.date(2008, 1, 1)
    end_date   = datetime.date.today()

    ranges = [(start_date, end_date)]
    all_users = []

    while ranges and len(all_users) < max_users:
        s, e = ranges.pop(0)
        created_q = f"created:{s.isoformat()}..{e.isoformat()}"
        query = f"location:{location} type:user {created_q}"

        count = get_user_count(query, url, headers)
        if count == 0:
            continue
        if count <= 1000:
            slice_users = paginated_search(query, min(count, max_users - len(all_users)), url, headers)
            for u in slice_users:
                if u not in all_users:
                    all_users.append(u)
                    if len(all_users) >= max_users:
                        break
        else:
            days = (e - s).days
            mid  = s + datetime.timedelta(days=days//2)
            ranges.insert(0, (mid + datetime.timedelta(days=1), e))
            ranges.insert(0, (s, mid))

    return all_users

def save_users_to_json(users, output_file):
    with open(output_file, 'w') as f:
        json.dump({"users": users}, f, indent=2)
    print(f"Saved {len(users)} users to {output_file}")

if __name__ == "__main__":
    TOKEN = "" #insertar token
    LOCATION = "France"  #seleccionas el país
    MAX_USERS = 1000  #numero de usuarios maximo
    OUTPUT_FILE = "github_users.json"  #luego de extraer cambiar el nombre a por ejemplo Spain_data.json

    print(f"Fetching {MAX_USERS} users in '{LOCATION}'...")
    users = fetch_users(LOCATION, MAX_USERS, TOKEN)
    print(f"→ Retrieved {len(users)} users.")

    save_users_to_json(users, OUTPUT_FILE)
# Out:
# Fetching 1000 users in 'France'...
# → Retrieved 1000 users.
# Saved 1000 users to github_users.json

# %% [markdown]
# ## 3. Extraemos la data de los usuarios y sus commit diarios en el mes de abril

# %%
import json
import time
import sys
from collections import defaultdict
from itertools import cycle
from pathlib import Path
from typing import Dict, List

import datetime as dt
import requests

START_DATE   = "2025-04-01"
END_DATE     = "2025-04-30"
TOKENS       = [ "" #insertar token

]
USERS_JSON   = "github_users.json"
OUTPUT_JSON  = "bd_commits_by_user.json"

try:
    dt.date.fromisoformat(START_DATE)
    dt.date.fromisoformat(END_DATE)
except ValueError:
    sys.exit("ERROR: START_DATE y END_DATE deben tener formato YYYY-MM-DD")

START_ISO = f"{START_DATE}T00:00:00Z"
END_ISO   = f"{END_DATE}T23:59:59Z"

COMMIT_QUERY = """
query($username:String!,$from:DateTime!,$to:DateTime!) {
  user(login:$username) {
    contributionsCollection(from:$from, to:$to) {
      totalCommitContributions
      contributionCalendar {
        weeks {
          contributionDays {
            date
            contributionCount
          }
        }
      }
    }
  }
}
"""

GQL_ENDPOINT = "https://api.github.com/graphql"


class RateLimitError(Exception):
    """Token agotado (5 000 peticiones/hora)."""
    pass


class TokenCycler:
    """Rota los PATs en cuanto ocurre rate‑limit."""
    def __init__(self, tokens: List[str]):
        if not tokens:
            raise ValueError("Debes definir al menos un token en TOKENS")
        self._tokens = cycle(tokens)
        self.current = next(self._tokens)

    def next(self) -> str:
        self.current = next(self._tokens)
        return self.current


def gql_request(query: str, variables: Dict, token: str) -> Dict:
    headers = {
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json",
        "Accept": "application/vnd.github.v3+json",
    }
    r = requests.post(GQL_ENDPOINT, json={"query": query, "variables": variables}, headers=headers)
    if r.status_code == 403 and "rate limit exceeded" in r.text.lower():
        raise RateLimitError()
    r.raise_for_status()
    payload = r.json()

    if "errors" in payload:
        for err in payload["errors"]:
            if err.get("type") == "RATE_LIMITED" or "rate limit" in err.get("message", "").lower():
                raise RateLimitError()
    return payload.get("data", {})


def load_users(path: str) -> List[str]:
    with open(path, "r") as f:
        data = json.load(f)
    users = data.get("users", [])
    if not users:
        sys.exit(f"ERROR: {path} no contiene la lista 'users'.")
    print(f"→ {len(users):,} usuarios cargados desde {path}")
    return users


def fetch_commits_by_user(
    users: List[str],
    start_iso: str,
    end_iso: str,
    token_cycler: TokenCycler,
    resume_json: Path,
) -> Dict[str, Dict]:
    """Devuelve {username: {"total_commits": int, "daily_commits": {...}}}."""
    if resume_json.exists():
        with open(resume_json, "r") as f:
            comm_data = json.load(f)
        processed = set(comm_data.keys())
        print(f"→ Reanudando: {len(processed):,} usuarios ya procesados")
    else:
        comm_data = {}
        processed = set()

    todo = [u for u in users if u not in processed]
    print(f"→ Quedan {len(todo):,} usuarios por procesar\n")

    for idx, login in enumerate(todo, 1):
        while True:
            try:
                vars_ = {"username": login, "from": start_iso, "to": end_iso}
                data = gql_request(COMMIT_QUERY, vars_, token_cycler.current)
                u = data.get("user")

                if not u or not u.get("contributionsCollection"):
                    print(f"   ○ {login}: sin datos")
                    break

                total = u["contributionsCollection"]["totalCommitContributions"]
                daily = defaultdict(int)
                for week in u["contributionsCollection"]["contributionCalendar"]["weeks"]:
                    for day in week["contributionDays"]:
                        c = day["contributionCount"]
                        if c:
                            daily[day["date"]] += c

                comm_data[login] = {
                    "total_commits": total,
                    "daily_commits": daily,
                }
                print(f"   • {login}: {total} commits ({len(daily)} días)")
                break

            except RateLimitError:
                old = token_cycler.current
                new = token_cycler.next()
                print(f"🔄 Token {old[:10]}… agotado → usando {new[:10]}…")
                time.sleep(1)

            except Exception as e:
                print(f"⚠️  {login}: error → {e}")
                break

        if idx % 100 == 0 or idx == len(todo):
            with open(resume_json, "w") as f:
                json.dump(comm_data, f, indent=2)
            print(f"💾 guardado parcial ({idx}/{len(todo)})\n")

    return comm_data


def main() -> None:
    token_cycler = TokenCycler(TOKENS)
    users = load_users(USERS_JSON)
    results = fetch_commits_by_user(
        users,
        start_iso=START_ISO,
        end_iso=END_ISO,
        token_cycler=token_cycler,
        resume_json=Path(OUTPUT_JSON),
    )

    total_users = len(results)
    total_commits = sum(d["total_commits"] for d in results.values())
    print("\n────────── Resumen final ──────────")
    print(f"Usuarios con commits: {total_users:,}")
    print(f"Commits totales:      {total_commits:,}")
    print(f"Archivo guardado en:  {OUTPUT_JSON}")


if __name__ == "__main__":
    main()
# Out:
# → 1,000 usuarios cargados desde github_users.json
# → Quedan 1,000 usuarios por procesar
#
#    • fabpot: 111 commits (21 días)
#    • benoitc: 0 commits (3 días)
#    • jd: 10 commits (11 días)
#    • byroot: 146 commits (26 días)
#    • n1k0: 16 commits (18 días)
#    • tdd: 1 commits (1 días)
#    • vdemeester: 136 commits (21 días)
#    • cgrand: 18 commits (7 días)
#    • glaforge: 4 commits (7 días)
#    • lindenb: 11 commits (9 días)
#    • jponge: 29 commits (13 días)
#    • luislavena: 29 commits (19 días)
#    • thoas: 3 commits (18 días)
#    • cveneziani: 25 commits (22 días)
#    • sunny: 43 commits (27 días)
#    • yannickcr: 0 commits (18 días)
#    • patcito: 0 commits (14 días)
#    • Ovid: 33 commits (6 días)
#    • dmathieu: 121 commits (22 días)
#    • nono: 10 commits (6 días)
#    • regisb: 31 commits (16 días)
#    • Cpasjuste: 1 commits (1 días)
#    • thbar: 7 commits (14 días)
#    • abique: 3 commits (6 días)
#    • fdv: 0 commits (0 días)
#    • ysbaddaden: 36 commits (23 días)
#    • noirbizarre: 31 commits (27 días)
#    • noteflakes: 10 commits (4 días)
#    • Delapouite: 8 commits (5 días)
#    • mistic100: 23 commits (10 días)
#    • wdavidw: 0 commits (0 días)
#    • pcarrier: 65 commits (22 días)
#    • masterzen: 0 commits (21 días)
#    • pcreux: 0 commits (19 días)
#    • thomasleveil: 14 commits (12 días)
#    • hartym: 23 commits (15 días)
#    • samueltardieu: 126 commits (16 días)
#    • Rydgel: 0 commits (1 días)
#    • davidB: 74 commits (19 días)
#    • jhchabran: 0 commits (19 días)
#    • sleeper: 6 commits (7 días)
#    • vegard: 0 commits (0 días)
#    • sbellity: 0 commits (18 días)
#    • Yoric: 4 commits (7 días)
#    • jmesnil: 19 commits (6 días)
#    • book: 2 commits (7 días)
#    • shingara: 0 commits (7 días)
#    • nicoulaj: 0 commits (0 días)
#    • yaf: 19 commits (14 días)
#    • renchap: 5 commits (23 días)
#    • np: 1 commits (3 días)
#    • crohr: 87 commits (14 días)
#    • linkdd: 93 commits (25 días)
#    • abailly: 101 commits (24 días)
#    • brunobord: 9 commits (3 días)
#    • tibastral: 20 commits (5 días)
#    • rymai: 0 commits (0 días)
#    • etiennebarrie: 61 commits (20 días)
#    • nadouani: 0 commits (0 días)
#    • ubitux: 2 commits (1 días)
#    • Zenithar: 2 commits (9 días)
#    • glejeune: 0 commits (0 días)
#    • sbz: 14 commits (2 días)
#    • jbbarth: 0 commits (20 días)
#    • erwan: 5 commits (19 días)
#    • philou: 697 commits (30 días)
#    • camilleroux: 0 commits (9 días)
#    • rhaamo: 74 commits (6 días)
#    • rikrd: 2 commits (1 días)
#    • AMorgaut: 1 commits (1 días)
#    • ericabouaf: 0 commits (16 días)
#    • Nyco: 0 commits (0 días)
#    • Florent2: 0 commits (0 días)
#    • nlamirault: 65 commits (8 días)
#    • PhilipDeegan: 12 commits (14 días)
#    • bertux: 12 commits (14 días)
#    • robertpi: 0 commits (5 días)
#    • Tristramg: 19 commits (9 días)
#    • mildred: 0 commits (17 días)
#    • artemave: 3 commits (4 días)
#    • joelthelion: 0 commits (0 días)
#    • edas: 0 commits (0 días)
#    • vincent: 24 commits (13 días)
#    • tgautier: 2 commits (2 días)
#    • lebigot: 0 commits (0 días)
#    • Spone: 0 commits (15 días)
#    • vbehar: 5 commits (3 días)
#    • joenio: 3 commits (3 días)
#    • cparnot: 0 commits (0 días)
#    • ana: 1 commits (2 días)
#    • rik: 8 commits (11 días)
#    • dams: 0 commits (15 días)
#    • loris: 0 commits (0 días)
#    • cbenz: 0 commits (0 días)
#    • hthetiot: 0 commits (16 días)
#    • cstar: 0 commits (7 días)
#    • maxime: 0 commits (0 días)
#    • gwik: 0 commits (1 días)
#    • jplang: 0 commits (0 días)
#    • madx: 1 commits (1 días)
# 💾 guardado parcial (100/1000)
#
#    • jeantil: 10 commits (5 días)
#    • piouPiouM: 0 commits (0 días)
#    • moy: 0 commits (0 días)
#    • xblaster: 0 commits (1 días)
#    • fab13n: 9 commits (17 días)
#    • etix: 0 commits (0 días)
#    • galdor: 35 commits (11 días)
#    • zepojo: 0 commits (14 días)
#    • bbenezech: 43 commits (16 días)
#    • jeffd: 0 commits (17 días)
#    • zedalaye: 9 commits (4 días)
#    • mickey: 0 commits (0 días)
#    • PhenX: 10 commits (7 días)
#    • etaque: 0 commits (0 días)
#    • archiloque: 1 commits (1 días)
#    • abiaad: 0 commits (0 días)
#    • Adirelle: 0 commits (1 días)
#    • thibault: 74 commits (17 días)
#    • freqdec: 0 commits (0 días)
#    • 2xyo: 0 commits (0 días)
#    • Farzy: 9 commits (7 días)
#    • jlecour: 40 commits (12 días)
#    • yannski: 0 commits (0 días)
#    • sroccaserra: 3 commits (3 días)
#    • jiho: 4 commits (5 días)
#    • olivM: 0 commits (27 días)
#    • desaintmartin: 20 commits (9 días)
#    • klaude: 0 commits (0 días)
#    • ook: 0 commits (12 días)
#    • rouffj: 0 commits (0 días)
#    • schmurfy: 0 commits (14 días)
#    • vrybas: 0 commits (11 días)
#    • engleek: 0 commits (0 días)
#    • fstrozzi: 0 commits (0 días)
#    • dator-zz: 0 commits (0 días)
#    • sigmike: 8 commits (3 días)
#    • i-nomads: 0 commits (0 días)
#    • martoche: 0 commits (0 días)
#    • borisfaure: 38 commits (24 días)
#    • flegoff: 0 commits (6 días)
#    • olasd: 46 commits (12 días)
#    • bergalath: 0 commits (18 días)
#    • panaggio: 0 commits (0 días)
#    • trivoallan: 256 commits (21 días)
#    • jchatard: 0 commits (0 días)
#    • skateinmars: 0 commits (10 días)
#    • parmanoir: 0 commits (0 días)
#    • njpearman: 0 commits (9 días)
#    • graouts: 13 commits (8 días)
#    • Flink: 355 commits (11 días)
#    • dohzya: 3 commits (4 días)
#    • micktaiwan: 0 commits (3 días)
#    • vguerra: 0 commits (2 días)
#    • rija: 5 commits (12 días)
#    • samleb: 0 commits (0 días)
#    • fridim: 13 commits (12 días)
#    • aegypius: 0 commits (15 días)
#    • nel: 0 commits (0 días)
#    • aymerick: 0 commits (13 días)
#    • msadouni: 0 commits (0 días)
#    • arnaud: 47 commits (9 días)
#    • pointcom: 0 commits (0 días)
#    • snostorm: 0 commits (0 días)
#    • gwenhael-le-moine: 67 commits (15 días)
#    • pcdavid: 31 commits (18 días)
#    • solisoft: 4 commits (4 días)
#    • izimobil: 0 commits (16 días)
#    • khelil: 0 commits (21 días)
#    • isc: 0 commits (22 días)
#    • chrisscholly: 0 commits (0 días)
#    • golgote: 0 commits (0 días)
#    • doches: 0 commits (0 días)
#    • jmgarnier: 0 commits (5 días)
#    • cgestes: 0 commits (1 días)
#    • berke: 0 commits (0 días)
#    • fuse: 0 commits (2 días)
#    • ArnaudD: 0 commits (17 días)
#    • momo54: 5 commits (3 días)
#    • zeno: 0 commits (0 días)
#    • JonathanTron: 1 commits (1 días)
#    • pbernery: 6 commits (16 días)
#    • cacaodev: 0 commits (0 días)
#    • jbfeldis: 26 commits (15 días)
#    • martinfilliau: 0 commits (3 días)
#    • bcaccinolo: 0 commits (0 días)
#    • jessy: 0 commits (10 días)
#    • scharrier: 0 commits (8 días)
#    • loopion: 0 commits (0 días)
#    • briot: 6 commits (3 días)
#    • czj: 0 commits (29 días)
#    • yanjost: 2 commits (21 días)
#    • RedFish: 0 commits (0 días)
#    • Gui13: 0 commits (0 días)
#    • loicboutet: 0 commits (0 días)
#    • Bastes: 16 commits (12 días)
#    • MiloCasagrande: 0 commits (14 días)
#    • touv: 15 commits (6 días)
#    • fanf: 52 commits (14 días)
#    • meuble: 0 commits (4 días)
#    • bricecarpentier: 10 commits (2 días)
# 💾 guardado parcial (200/1000)
#
#    • enzbang: 0 commits (0 días)
#    • blat: 0 commits (0 días)
#    • fte: 0 commits (0 días)
#    • Bounga: 0 commits (0 días)
#    • adrieng: 0 commits (2 días)
#    • nl: 0 commits (0 días)
#    • bikerduweb: 0 commits (0 días)
#    • goodtouch: 13 commits (3 días)
#    • madmatah: 0 commits (0 días)
#    • gauthier: 0 commits (4 días)
#    • goldoraf: 0 commits (15 días)
#    • lstep: 0 commits (6 días)
#    • mathieu: 0 commits (0 días)
#    • digitalfox: 8 commits (9 días)
#    • lebesnec: 24 commits (2 días)
#    • egrajeda: 1 commits (1 días)
#    • ypelud: 0 commits (0 días)
#    • Korko: 0 commits (0 días)
#    • ppierre: 0 commits (0 días)
#    • LekisS: 0 commits (0 días)
#    • nfo: 0 commits (0 días)
#    • vanicat: 0 commits (0 días)
#    • thb: 0 commits (0 días)
#    • helix: 0 commits (0 días)
#    • ncrovatti: 0 commits (5 días)
#    • hanklords: 0 commits (0 días)
#    • defro: 5 commits (4 días)
#    • corenting: 39 commits (14 días)
#    • ByScripts: 3 commits (5 días)
#    • quentin: 1 commits (2 días)
#    • cyrill62: 0 commits (12 días)
#    • dbourguignon: 0 commits (16 días)
#    • evaisse: 0 commits (1 días)
#    • pixel: 0 commits (0 días)
#    • bmillemathias: 4 commits (5 días)
#    • cognominal: 63 commits (16 días)
#    • audebert: 0 commits (0 días)
#    • fmarcia: 0 commits (0 días)
#    • rcaetano: 0 commits (0 días)
#    • phtrivier: 0 commits (0 días)
#    • hellvinz: 0 commits (19 días)
#    • jpcaruana: 3 commits (3 días)
#    • gmarabout-zz: 0 commits (0 días)
#    • mikepulaski: 0 commits (20 días)
#    • rds13: 0 commits (1 días)
#    • yvon: 5 commits (1 días)
#    • jerome: 0 commits (0 días)
#    • roolio: 0 commits (1 días)
#    • waern: 0 commits (0 días)
#    • banux: 0 commits (15 días)
#    • vaucouleur: 0 commits (9 días)
#    • tonio: 0 commits (21 días)
#    • vincentp: 0 commits (0 días)
#    • FrenchW: 0 commits (0 días)
#    • michelc: 9 commits (8 días)
#    • inthehack: 0 commits (0 días)
#    • githubber: 0 commits (2 días)
#    • fmalamitsas: 0 commits (0 días)
#    • fmauNeko: 0 commits (4 días)
#    • Fraggle: 49 commits (25 días)
#    • justine: 0 commits (0 días)
#    • fjolliton: 11 commits (11 días)
#    • kassoulet: 0 commits (0 días)
#    • mickro: 0 commits (0 días)
#    • karouf: 0 commits (19 días)
#    • sleberrigaud: 0 commits (0 días)
#    • mannd: 84 commits (20 días)
#    • benoit-canet: 0 commits (0 días)
#    • anicolas: 0 commits (12 días)
#    • Zai: 0 commits (0 días)
#    • bdauvergne: 0 commits (0 días)
#    • 0livier: 0 commits (0 días)
#    • kpitn: 0 commits (14 días)
#    • davefrey: 0 commits (0 días)
#    • djtal: 0 commits (0 días)
#    • vberetti: 0 commits (0 días)
#    • Youx: 0 commits (1 días)
#    • fdevillamil: 0 commits (0 días)
#    • elcerdo: 1 commits (2 días)
#    • Ced: 0 commits (0 días)
#    • krachot: 0 commits (17 días)
#    • sebthemonster: 0 commits (0 días)
#    • ccamensuli: 0 commits (0 días)
#    • devsigner: 0 commits (17 días)
#    • ouvanous: 0 commits (0 días)
#    • ahfeel: 0 commits (2 días)
#    • jlefrique: 0 commits (0 días)
#    • franee: 0 commits (21 días)
#    • tehf0x: 0 commits (0 días)
#    • jocelyngirard: 0 commits (2 días)
#    • jlopinto: 0 commits (16 días)
#    • bartocc: 0 commits (20 días)
#    • fbeauchamp: 9 commits (14 días)
#    • jej: 0 commits (0 días)
#    • splo: 30 commits (6 días)
#    • ngonzalez: 0 commits (4 días)
#    • glebiller: 0 commits (0 días)
#    • 2072: 0 commits (1 días)
#    • shanser: 0 commits (0 días)
#    • Electron-libre: 0 commits (0 días)
# 💾 guardado parcial (300/1000)
#
#    • AltiusRupert: 0 commits (0 días)
#    • najmam: 37 commits (6 días)
#    • kvpb: 0 commits (0 días)
#    • nfonrose: 0 commits (0 días)
#    • marcanpilami: 0 commits (7 días)
#    • hanni-zz: 0 commits (0 días)
#    • kouak: 0 commits (0 días)
#    • webpulser: 0 commits (0 días)
#    • nsteinmetz: 0 commits (0 días)
#    • zeroheure: 17 commits (7 días)
#    • nobert: 0 commits (0 días)
#    • loig: 0 commits (16 días)
#    • jeje: 0 commits (5 días)
#    • blino: 0 commits (0 días)
#    • adyxax: 67 commits (29 días)
#    • AntoninHL: 0 commits (2 días)
#    • CharlyBr: 0 commits (15 días)
#    • Sylvain: 0 commits (1 días)
#    • jmoussalli: 0 commits (1 días)
#    • mhammiche: 0 commits (0 días)
#    • mimo: 0 commits (0 días)
#    • Bivi: 0 commits (0 días)
#    • sylvaindesve: 0 commits (0 días)
#    • csar: 0 commits (0 días)
#    • francisoud: 0 commits (0 días)
#    • asynkayo: 0 commits (0 días)
#    • nowhereman: 0 commits (0 días)
#    • Cidotis: 0 commits (0 días)
#    • Amo: 0 commits (14 días)
#    • grosours: 0 commits (0 días)
#    • Ezor: 0 commits (0 días)
#    • vdubois: 0 commits (0 días)
#    • lbois: 0 commits (2 días)
#    • Titinux: 0 commits (0 días)
#    • maspalio: 0 commits (0 días)
#    • bartcortooms: 0 commits (0 días)
#    • FabienGandon: 0 commits (0 días)
#    • lemarsu: 0 commits (0 días)
#    • slubman: 0 commits (0 días)
#    • ljouglar: 0 commits (0 días)
#    • be1: 50 commits (8 días)
#    • reivilo: 0 commits (0 días)
#    • elbabass: 0 commits (0 días)
#    • snouhaud: 0 commits (0 días)
#    • forbairt: 0 commits (0 días)
#    • blacksun: 0 commits (0 días)
#    • vendeesign: 0 commits (0 días)
#    • fjanon: 0 commits (0 días)
#    • ljulliar: 38 commits (6 días)
#    • gdufloux: 0 commits (18 días)
#    • Nukium: 0 commits (0 días)
#    • glurp: 0 commits (0 días)
#    • seventh: 0 commits (0 días)
#    • Rapiere: 0 commits (1 días)
#    • vmulot: 0 commits (0 días)
#    • bhuron: 0 commits (0 días)
#    • nbc: 1 commits (2 días)
#    • rhardouin: 0 commits (19 días)
#    • dsoulayrol: 0 commits (0 días)
#    • sinarf: 1 commits (1 días)
#    • josrzn: 0 commits (0 días)
#    • aljeux: 0 commits (0 días)
#    • jmvallet: 0 commits (0 días)
#    • BorisBP: 0 commits (0 días)
#    • lfarcy: 0 commits (0 días)
#    • ced1870: 0 commits (0 días)
#    • optyler: 0 commits (12 días)
#    • pilap82: 0 commits (0 días)
#    • AnCaRioN: 0 commits (0 días)
#    • atrepp: 0 commits (0 días)
#    • tifredfr: 0 commits (1 días)
#    • jonathanbelolo: 0 commits (0 días)
#    • ThQ: 0 commits (0 días)
#    • emcastro: 19 commits (11 días)
#    • nightlybuild: 0 commits (0 días)
#    • dpithon: 0 commits (0 días)
#    • marco-zz: 0 commits (0 días)
#    • hugobqd: 0 commits (1 días)
#    • franck: 1 commits (17 días)
#    • bthery: 0 commits (0 días)
#    • TiteFleur: 0 commits (0 días)
#    • harryseldon: 0 commits (0 días)
#    • ncouturier: 0 commits (0 días)
#    • Gigelf: 0 commits (0 días)
#    • scolin: 0 commits (0 días)
#    • jcm: 0 commits (0 días)
#    • tbarthelet: 0 commits (0 días)
#    • alxdrl: 8 commits (3 días)
#    • virtualmice: 0 commits (0 días)
#    • flop: 0 commits (1 días)
#    • NicolasP: 0 commits (0 días)
#    • jtek: 0 commits (0 días)
#    • earlieszombie: 0 commits (1 días)
#    • cgodefroy: 0 commits (0 días)
#    • Kusanar: 0 commits (0 días)
#    • mpalomas: 32 commits (20 días)
#    • briancouchman: 0 commits (0 días)
#    • OMEOUS: 0 commits (0 días)
#    • strass-zz: 0 commits (0 días)
#    • mbrung: 0 commits (0 días)
# 💾 guardado parcial (400/1000)
#
#    • lzubac: 0 commits (0 días)
#    • kib2: 0 commits (0 días)
#    • badal: 0 commits (0 días)
#    • gspettel: 0 commits (0 días)
#    • tinoucas: 0 commits (0 días)
#    • jmd: 0 commits (0 días)
#    • opcode: 0 commits (0 días)
#    • ssawda: 0 commits (0 días)
#    • wizidot: 0 commits (0 días)
#    • Plume-xx: 0 commits (0 días)
#    • PanPan-zz: 0 commits (0 días)
#    • hookipaa: 0 commits (0 días)
#    • Nauhaie: 0 commits (0 días)
#    • aga037: 0 commits (0 días)
#    • awilhelm: 0 commits (0 días)
#    • ykereun: 0 commits (0 días)
#    • mazembo: 0 commits (0 días)
#    • bloutix: 0 commits (0 días)
#    • shmitix: 0 commits (0 días)
#    • 2mx: 0 commits (0 días)
#    • eino: 1 commits (1 días)
#    • nagubal: 0 commits (0 días)
#    • Airod: 0 commits (0 días)
#    • nbaroiller: 0 commits (0 días)
#    • evenremy: 0 commits (0 días)
#    • asirinelli: 0 commits (0 días)
#    • Desintegr: 0 commits (0 días)
#    • Ashaan: 0 commits (0 días)
#    • zikinf: 0 commits (0 días)
#    • Tibi: 0 commits (0 días)
#    • davidaff: 0 commits (0 días)
#    • tpkennes: 0 commits (0 días)
#    • bmironer: 0 commits (0 días)
#    • humanite: 0 commits (0 días)
#    • brunobl: 0 commits (0 días)
#    • garetharmstronghp: 0 commits (0 días)
#    • Yusei: 0 commits (0 días)
#    • pvet: 0 commits (0 días)
#    • RoPP: 0 commits (0 días)
#    • mimikn: 0 commits (16 días)
#    • FunkeyMonkeys: 0 commits (0 días)
#    • GaLi: 0 commits (0 días)
#    • yzack: 0 commits (0 días)
#    • clescuyer: 0 commits (0 días)
#    • dju: 0 commits (0 días)
#    • abrausch: 0 commits (0 días)
#    • fredericbertin: 0 commits (0 días)
#    • fperrad: 0 commits (0 días)
#    • dexter74: 0 commits (0 días)
#    • nadimkobeissi: 0 commits (0 días)
#    • jaime-madrid-avila: 0 commits (0 días)
#    • ogrisel: 28 commits (18 días)
#    • dunglas: 37 commits (16 días)
#    • cyrilmottier: 0 commits (0 días)
#    • fzaninotto: 69 commits (16 días)
#    • donho: 24 commits (20 días)
#    • moul: 72 commits (24 días)
#    • bclozel: 45 commits (9 días)
#    • groue: 16 commits (4 días)
#    • dimitri: 12 commits (8 días)
#    • mgcrea: 29 commits (8 días)
#    • Synchro: 13 commits (7 días)
#    • jpauli: 0 commits (0 días)
#    • mklabs: 12 commits (16 días)
#    • VonC: 9 commits (17 días)
#    • almet: 13 commits (9 días)
#    • eko: 21 commits (24 días)
#    • gritzko: 0 commits (0 días)
#    • paraboul: 0 commits (14 días)
#    • DirtyF: 0 commits (0 días)
#    • NiLuJe: 99 commits (17 días)
#    • garuma: 0 commits (0 días)
#    • yogsototh: 0 commits (16 días)
#    • DjebbZ: 0 commits (1 días)
#    • docteurklein: 0 commits (0 días)
#    • texane: 0 commits (0 días)
#    • j0k3r: 32 commits (18 días)
#    • nhoizey: 231 commits (30 días)
#    • gnodet: 37 commits (22 días)
#    • Fantomas42: 262 commits (28 días)
#    • mremond: 0 commits (3 días)
#    • julienXX: 0 commits (1 días)
#    • APE-Project: 0 commits (0 días)
#    • adriengibrat: 4 commits (1 días)
#    • metal3d: 57 commits (8 días)
#    • francois2metz: 14 commits (19 días)
#    • pi8027: 15 commits (10 días)
#    • ArnaudLigny: 112 commits (13 días)
#    • Minishlink: 19 commits (4 días)
#    • chanmix51: 0 commits (0 días)
#    • chmouel: 74 commits (20 días)
#    • mathieucarbou: 101 commits (20 días)
#    • bstarynk: 68 commits (19 días)
#    • sukria: 0 commits (27 días)
#    • glenux: 2 commits (2 días)
#    • nojb: 12 commits (27 días)
#    • jegnux: 1 commits (4 días)
#    • chikamichi: 0 commits (0 días)
#    • vincentfretin: 9 commits (14 días)
#    • gounthar: 528 commits (28 días)
# 💾 guardado parcial (500/1000)
#
#    • shouze: 63 commits (22 días)
#    • ahoy-jon: 10 commits (9 días)
#    • happypoulp: 0 commits (0 días)
#    • anoiaque: 0 commits (0 días)
#    • robink: 0 commits (26 días)
#    • redaready: 0 commits (0 días)
#    • michiard: 0 commits (0 días)
#    • nulltoken: 27 commits (12 días)
#    • JrCs: 0 commits (0 días)
#    • mpg: 18 commits (13 días)
#    • maddingue: 16 commits (7 días)
#    • vpicavet: 0 commits (0 días)
#    • kbsali: 0 commits (15 días)
#    • romseguy: 0 commits (0 días)
#    • jawher: 1 commits (30 días)
#    • jvelo: 0 commits (29 días)
#    • ngrunwald: 0 commits (0 días)
#    • eroux: 53 commits (23 días)
#    • nbareil: 0 commits (1 días)
#    • priteau: 19 commits (12 días)
#    • peczenyj: 40 commits (8 días)
#    • Schnouki: 13 commits (20 días)
#    • rasata: 12 commits (9 días)
#    • phantez: 0 commits (0 días)
#    • Artefact2: 11 commits (4 días)
#    • sanpii: 42 commits (9 días)
#    • nizox: 0 commits (23 días)
#    • gboissinot: 0 commits (0 días)
#    • arntanguy: 39 commits (14 días)
#    • Amokrane: 0 commits (0 días)
#    • roza: 4 commits (2 días)
#    • PsychoH13: 0 commits (2 días)
#    • tmortagne: 134 commits (17 días)
#    • tiennou: 0 commits (0 días)
#    • andreivolt: 0 commits (0 días)
#    • gyndav: 1 commits (18 días)
#    • cappert: 0 commits (0 días)
#    • eexit: 8 commits (19 días)
#    • laurentpetit: 0 commits (0 días)
#    • TaurusOlson: 0 commits (0 días)
#    • laurentb: 0 commits (0 días)
#    • Ecco: 0 commits (2 días)
#    • boulabiar: 0 commits (0 días)
#    • garaud: 5 commits (14 días)
#    • marcyves: 4 commits (3 días)
#    • mazurov: 0 commits (0 días)
#    • iamdey: 0 commits (0 días)
#    • RobertDober: 1 commits (1 días)
#    • jan0: 0 commits (0 días)
#    • shimaore: 3 commits (3 días)
#    • elishowk: 0 commits (12 días)
#    • acemtp: 0 commits (16 días)
#    • hervehobbes: 0 commits (1 días)
#    • abompard: 58 commits (19 días)
#    • pyke369: 4 commits (2 días)
#    • dickolsson: 0 commits (0 días)
#    • freesteph: 142 commits (18 días)
#    • Alexis211: 0 commits (0 días)
#    • djcoin: 0 commits (0 días)
#    • breard-r: 0 commits (0 días)
#    • sahid: 0 commits (0 días)
#    • oncleben31: 0 commits (0 días)
#    • alessandroleite: 0 commits (0 días)
#    • qmathe: 0 commits (0 días)
#    • mgautierfr: 39 commits (13 días)
#    • hsyl20: 6 commits (5 días)
#    • magnet: 0 commits (0 días)
#    • r3trofitted: 0 commits (20 días)
#    • ehsavoie: 32 commits (13 días)
#    • Aqua-Ye: 0 commits (20 días)
#    • azmeuk: 150 commits (26 días)
#    • mretegan: 0 commits (2 días)
#    • vperron: 9 commits (8 días)
#    • Fy-: 86 commits (8 días)
#    • ndechesne: 15 commits (11 días)
#    • ebouchut: 57 commits (14 días)
#    • lucabelluccini: 0 commits (12 días)
#    • vipom: 0 commits (0 días)
#    • kaicarver: 3 commits (2 días)
#    • ker2x: 0 commits (0 días)
#    • gaspaio: 0 commits (0 días)
#    • zetaben: 0 commits (21 días)
#    • juliendorra: 122 commits (19 días)
#    • ehartmann: 0 commits (9 días)
#    • yanndinendal: 4 commits (3 días)
#    • bobot: 3 commits (4 días)
#    • mdcarter: 0 commits (4 días)
#    • Kazy: 3 commits (25 días)
#    • spawnrider: 13 commits (3 días)
#    • pierrejean-coudert: 0 commits (12 días)
#    • richardbarran: 0 commits (0 días)
#    • jeromelebel: 0 commits (0 días)
#    • ecolinet: 0 commits (0 días)
#    • jpbarrette: 0 commits (0 días)
#    • leogomes: 0 commits (0 días)
#    • smaret: 2 commits (4 días)
#    • gphilipp: 0 commits (1 días)
#    • Veejay: 0 commits (0 días)
#    • ofavre: 21 commits (6 días)
#    • gkfabs: 1 commits (2 días)
# 💾 guardado parcial (600/1000)
#
#    • padawan: 0 commits (3 días)
#    • kaaloo: 100 commits (16 días)
#    • romuald: 1 commits (2 días)
#    • chreble: 0 commits (4 días)
#    • clem: 0 commits (0 días)
#    • jcarsique: 0 commits (0 días)
#    • grevaillot: 0 commits (14 días)
#    • loicguillois: 21 commits (9 días)
#    • moa3: 0 commits (0 días)
#    • arthurlutz: 0 commits (0 días)
#    • afranke: 4 commits (4 días)
#    • nezetic: 0 commits (0 días)
#    • klando: 0 commits (0 días)
#    • jquelin: 0 commits (0 días)
#    • uiteoi: 0 commits (0 días)
#    • unflores: 2 commits (1 días)
#    • La0: 2 commits (4 días)
#    • ptitjes: 0 commits (0 días)
#    • kevinmuller: 0 commits (0 días)
#    • humboldtux: 5 commits (16 días)
#    • NebJ: 0 commits (0 días)
#    • theod: 0 commits (0 días)
#    • twktheainur: 0 commits (0 días)
#    • bastienlabelle: 0 commits (16 días)
#    • 4e4c52: 0 commits (0 días)
#    • celogeek: 1 commits (1 días)
#    • tyjak: 0 commits (0 días)
#    • jeremiecook: 0 commits (0 días)
#    • rverdier: 0 commits (0 días)
#    • Oliv: 0 commits (7 días)
#    • trecloux: 0 commits (1 días)
#    • nicolas33: 0 commits (0 días)
#    • troger: 1 commits (10 días)
#    • mrzor: 0 commits (0 días)
#    • nlehuen: 0 commits (0 días)
#    • paour: 0 commits (19 días)
#    • mbuffa: 13 commits (15 días)
#    • j2l: 5 commits (5 días)
#    • halfbaked: 0 commits (0 días)
#    • Dagnan: 0 commits (7 días)
#    • sdeseille: 0 commits (0 días)
#    • slester: 0 commits (0 días)
#    • etiennepeiniau: 0 commits (0 días)
#    • bpaulin: 0 commits (0 días)
#    • mmai: 15 commits (8 días)
#    • nsorosac: 0 commits (0 días)
#    • odalet: 0 commits (0 días)
#    • gidouin: 0 commits (0 días)
#    • tofgarion: 0 commits (0 días)
#    • jbq: 0 commits (0 días)
#    • pix: 0 commits (0 días)
#    • cara-tm: 2 commits (2 días)
#    • EmileKroeger: 0 commits (9 días)
#    • jvdrean: 0 commits (11 días)
#    • ey3ball: 0 commits (0 días)
#    • Quezako: 0 commits (0 días)
#    • fpighi: 1 commits (18 días)
#    • romaintb: 0 commits (7 días)
#    • benoitberenger: 0 commits (1 días)
#    • nedbaldessin: 4 commits (3 días)
#    • neiluJ: 7 commits (1 días)
#    • Othella: 0 commits (13 días)
#    • PhilH: 0 commits (0 días)
#    • MrGecko: 0 commits (0 días)
#    • ebezault: 0 commits (0 días)
#    • Sephi-Chan: 0 commits (0 días)
#    • amalik: 0 commits (30 días)
#    • cyril-ponce: 0 commits (0 días)
#    • Obi-Wan: 37 commits (10 días)
#    • pli01: 1 commits (1 días)
#    • DougC: 0 commits (0 días)
#    • Jiboo: 0 commits (0 días)
#    • psish: 0 commits (0 días)
#    • leNEKO: 2 commits (1 días)
#    • squentin: 0 commits (0 días)
#    • ngirard: 0 commits (0 días)
#    • jdguyot: 0 commits (0 días)
#    • jooooooon: 0 commits (0 días)
#    • yalp: 0 commits (0 días)
#    • bilboed: 0 commits (0 días)
#    • chombourger: 3 commits (12 días)
#    • legzo: 0 commits (0 días)
#    • snarky: 0 commits (0 días)
#    • dpaccoud: 0 commits (0 días)
#    • yifu: 0 commits (0 días)
#    • stanguy: 0 commits (0 días)
#    • moechofe: 2 commits (3 días)
#    • vincent-petithory: 0 commits (0 días)
#    • labilbe: 0 commits (0 días)
#    • daks: 0 commits (0 días)
#    • nicomollet: 0 commits (13 días)
#    • vhardy: 0 commits (0 días)
#    • eburghar: 0 commits (0 días)
#    • fpeyraud: 0 commits (0 días)
#    • mgu: 0 commits (1 días)
#    • jhominal: 0 commits (0 días)
#    • Christophe31: 0 commits (0 días)
#    • philippeko: 0 commits (0 días)
#    • doud: 0 commits (0 días)
#    • gbilder: 1 commits (2 días)
# 💾 guardado parcial (700/1000)
#
#    • zoc: 0 commits (0 días)
#    • tristandaeschner: 0 commits (0 días)
#    • KuSh: 2 commits (2 días)
#    • lpoujol: 0 commits (0 días)
#    • kelexel: 0 commits (0 días)
#    • iuliansafta: 2 commits (2 días)
#    • dieppe: 0 commits (0 días)
#    • ocornu: 0 commits (0 días)
#    • adamico: 44 commits (7 días)
#    • jcbertin: 0 commits (0 días)
#    • brds: 0 commits (13 días)
#    • ze0n: 0 commits (0 días)
#    • vincentdephily: 0 commits (1 días)
#    • voxdei: 0 commits (0 días)
#    • clongeau: 0 commits (1 días)
#    • MrMoins: 0 commits (26 días)
#    • chtipepere: 0 commits (0 días)
#    • pbrochard: 0 commits (17 días)
#    • JoN1oP: 0 commits (19 días)
#    • earzur: 0 commits (0 días)
#    • Taliii: 0 commits (0 días)
#    • fjg: 0 commits (0 días)
#    • d-tux: 0 commits (0 días)
#    • Lockeid: 0 commits (15 días)
#    • grm: 0 commits (0 días)
#    • vladzloteanu: 0 commits (0 días)
#    • sinclairfr: 42 commits (8 días)
#    • ObjectifMars: 0 commits (0 días)
#    • osaut: 0 commits (0 días)
#    • josf: 0 commits (12 días)
#    • gudoy: 0 commits (0 días)
#    • thomassloboda: 12 commits (13 días)
#    • kurotoshiro: 0 commits (0 días)
#    • gcerquant: 0 commits (0 días)
#    • xcombelle: 0 commits (0 días)
#    • cornuwel: 0 commits (5 días)
#    • YohannsMonnier: 0 commits (0 días)
#    • rboissat: 0 commits (0 días)
#    • Gorcyn: 0 commits (0 días)
#    • organicweb: 0 commits (0 días)
#    • Floriaen: 0 commits (0 días)
#    • zandev: 0 commits (0 días)
#    • chrc: 9 commits (4 días)
#    • kochka: 0 commits (0 días)
#    • kissifrot: 4 commits (21 días)
#    • rayene: 0 commits (0 días)
#    • charlesruelle: 0 commits (0 días)
#    • konogan: 0 commits (0 días)
#    • hichem: 0 commits (0 días)
#    • nmussat: 3 commits (1 días)
#    • tyeum: 0 commits (0 días)
#    • mallain: 0 commits (0 días)
#    • jbelis: 0 commits (0 días)
#    • npelloux: 0 commits (0 días)
#    • chaoskaizer: 0 commits (0 días)
#    • Lakedaemon: 0 commits (1 días)
#    • dnonnenm: 0 commits (0 días)
#    • aixtal: 0 commits (0 días)
#    • thomasdeniau: 0 commits (0 días)
#    • cedricmauclair: 0 commits (0 días)
#    • tophe: 0 commits (0 días)
#    • pplr: 0 commits (0 días)
#    • seboudry: 0 commits (0 días)
#    • gwendoux: 0 commits (0 días)
#    • noodleagency: 0 commits (0 días)
#    • Toniob: 0 commits (1 días)
#    • mmith: 0 commits (0 días)
#    • quetzal: 0 commits (0 días)
#    • lxs: 0 commits (0 días)
#    • Siegels: 0 commits (0 días)
#    • rivsc: 0 commits (0 días)
#    • yoannsaludes: 0 commits (0 días)
#    • mhofongfat: 0 commits (0 días)
#    • agencecosmic: 0 commits (0 días)
#    • fredericbarrau: 0 commits (0 días)
#    • juliennicouleaud: 0 commits (0 días)
#    • beeNotice: 0 commits (0 días)
#    • grimko: 0 commits (1 días)
#    • sdesbure: 3 commits (2 días)
#    • vladoro: 0 commits (0 días)
#    • lescoste: 0 commits (0 días)
#    • nicoclavier: 0 commits (0 días)
#    • neni: 0 commits (0 días)
#    • thibaud: 0 commits (0 días)
#    • gcachet: 0 commits (0 días)
#    • tomb: 0 commits (0 días)
#    • halgandd: 0 commits (0 días)
#    • andreadecorte: 19 commits (19 días)
#    • dada87: 0 commits (0 días)
#    • davidblondeau: 0 commits (0 días)
#    • MikeAski: 0 commits (0 días)
#    • aureliensibiril: 0 commits (0 días)
#    • dbee: 0 commits (0 días)
#    • mvachette: 0 commits (0 días)
#    • AirMarty: 0 commits (0 días)
#    • tuf: 0 commits (0 días)
#    • sl1200mk2: 0 commits (0 días)
#    • cariboo: 0 commits (0 días)
#    • mayweed: 0 commits (0 días)
#    • lcprod: 0 commits (0 días)
# 💾 guardado parcial (800/1000)
#
#    • sylvaing: 1 commits (1 días)
#    • ttiot: 0 commits (1 días)
#    • Shnalla: 0 commits (0 días)
#    • lcortier: 0 commits (0 días)
#    • Silocan: 0 commits (1 días)
#    • fblanc: 0 commits (0 días)
#    • ebl: 0 commits (0 días)
#    • nicolakis: 0 commits (0 días)
#    • lboulard: 99 commits (30 días)
#    • vdust: 0 commits (0 días)
#    • Nuky: 0 commits (0 días)
#    • cseyve: 0 commits (0 días)
#    • ggodet-bar: 0 commits (0 días)
#    • Arclight80: 0 commits (0 días)
#    • cups: 0 commits (0 días)
#    • rndmerle: 0 commits (2 días)
#    • fabienmoritz: 0 commits (0 días)
#    • shikamaru: 0 commits (0 días)
#    • floutre: 0 commits (0 días)
#    • cristal: 0 commits (0 días)
#    • knotty: 0 commits (0 días)
#    • irfantoor: 0 commits (0 días)
#    • nextmood: 0 commits (0 días)
#    • DanteTears: 0 commits (0 días)
#    • opensam: 0 commits (0 días)
#    • avitry: 0 commits (0 días)
#    • cfoellmi: 0 commits (0 días)
#    • sardak: 0 commits (0 días)
#    • raubel: 7 commits (4 días)
#    • stephanedeluca: 0 commits (0 días)
#    • gabacid: 0 commits (0 días)
#    • b4k4: 0 commits (0 días)
#    • Imaginos: 0 commits (0 días)
#    • stf8: 0 commits (0 días)
#    • vkergonna: 0 commits (0 días)
#    • rougerose: 90 commits (12 días)
#    • lohrun: 0 commits (0 días)
#    • froom: 0 commits (0 días)
#    • mobiluck: 0 commits (0 días)
#    • jphor: 0 commits (0 días)
#    • romainpreston: 0 commits (0 días)
#    • Indiana-: 0 commits (0 días)
#    • talkcarbon: 0 commits (0 días)
#    • erider: 0 commits (0 días)
#    • ArnaudVERSINI: 1 commits (1 días)
#    • savril: 0 commits (0 días)
#    • caerwyn: 0 commits (0 días)
#    • baptistenuez: 0 commits (9 días)
#    • cyrilruel: 0 commits (0 días)
#    • Thanh: 0 commits (0 días)
#    • vincent1870: 0 commits (0 días)
#    • ligne13: 0 commits (0 días)
#    • Gnist: 0 commits (0 días)
#    • sdubrau: 0 commits (0 días)
#    • FredBoucher: 0 commits (0 días)
#    • cjed: 0 commits (0 días)
#    • BinaryGastronome: 0 commits (0 días)
#    • jeromeattia: 0 commits (0 días)
#    • carbongarden: 0 commits (0 días)
#    • mh2ces: 0 commits (0 días)
#    • g76r: 65 commits (19 días)
#    • JBX028: 0 commits (0 días)
#    • mmluqman: 0 commits (0 días)
#    • guideon: 0 commits (0 días)
#    • briice: 0 commits (0 días)
#    • etrillaud: 0 commits (0 días)
#    • nicocunin: 0 commits (1 días)
#    • jpl: 0 commits (0 días)
#    • unevu: 0 commits (0 días)
#    • morphau: 0 commits (0 días)
#    • louisepalmer: 0 commits (0 días)
#    • docwho: 0 commits (0 días)
#    • choda: 0 commits (0 días)
#    • mercutio: 0 commits (0 días)
#    • uneek: 0 commits (0 días)
#    • SNerduino: 0 commits (0 días)
#    • thomasgalibert: 0 commits (0 días)
#    • babarocap: 0 commits (0 días)
#    • phantase: 0 commits (0 días)
#    • jeanbon: 0 commits (0 días)
#    • cheperboy: 0 commits (0 días)
#    • datoine: 0 commits (1 días)
#    • Kaimite: 0 commits (0 días)
#    • JWillow: 0 commits (0 días)
#    • nnay13: 0 commits (0 días)
#    • sdabet: 0 commits (0 días)
#    • pcrest: 0 commits (0 días)
#    • jdmuys: 0 commits (0 días)
#    • swafran: 0 commits (3 días)
#    • jruaud: 0 commits (0 días)
#    • skoot: 0 commits (0 días)
#    • johnnylattouf: 0 commits (0 días)
#    • gbredif: 0 commits (0 días)
#    • mobiluckeng: 0 commits (0 días)
#    • izvictor: 0 commits (0 días)
#    • nicolasfolliot: 0 commits (0 días)
#    • Xhelas: 0 commits (0 días)
#    • jlescudie: 0 commits (0 días)
#    • sebphil: 0 commits (0 días)
#    • sdelcros: 0 commits (0 días)
# 💾 guardado parcial (900/1000)
#
#    • baalhiverne: 0 commits (0 días)
#    • torticolix: 0 commits (0 días)
#    • malleronv: 0 commits (0 días)
#    • pgauthier: 0 commits (0 días)
#    • globule: 0 commits (0 días)
#    • xboudet: 0 commits (0 días)
#    • galactorus: 0 commits (0 días)
#    • deltrinos: 0 commits (0 días)
#    • Garroo: 0 commits (0 días)
#    • nodesfactory: 0 commits (0 días)
#    • adongy: 0 commits (0 días)
#    • ornicar: 594 commits (29 días)
#    • jedisct1: 641 commits (28 días)
#    • AliSoftware: 11 commits (11 días)
#    • cyrildiagne: 0 commits (4 días)
#    • gre: 0 commits (0 días)
#    • willdurand: 29 commits (16 días)
#    • Calinou: 112 commits (27 días)
#    • vstinner: 47 commits (24 días)
#    • agramfort: 3 commits (27 días)
#    • Geal: 1 commits (5 días)
#    • MoOx: 38 commits (21 días)
#    • revolunet: 48 commits (18 días)
#    • vvo: 6 commits (18 días)
#    • tpruvot: 0 commits (0 días)
#    • baskerville: 0 commits (0 días)
#    • kizu: 1 commits (20 días)
#    • FGRibreau: 1 commits (28 días)
#    • dgageot: 202 commits (28 días)
#    • steeve: 1 commits (1 días)
#    • jacomyal: 32 commits (14 días)
#    • thom4parisot: 29 commits (19 días)
#    • fpillet: 0 commits (0 días)
#    • ndeloof: 33 commits (13 días)
#    • NicolasPetton: 0 commits (8 días)
#    • kartben: 73 commits (29 días)
#    • nox: 0 commits (0 días)
#    • jaubourg: 0 commits (0 días)
#    • johnvuko: 22 commits (19 días)
#    • yohanboniface: 283 commits (17 días)
#    • waxzce: 0 commits (0 días)
